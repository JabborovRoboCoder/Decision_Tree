# %% [markdown]
# <a href="https://colab.research.google.com/github/JabborovRoboCoder/Decision_Tree/blob/main/Amaliyot_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Classification
#
# Decision Tree
#
# # Bemorga dori tavsiya qilish tizimi
#
# Tasavvur qiling, siz tadqiqot uchun ma'lumot to'playotgan tibbiy tadqiqotchisiz. Siz bir xil kasallikdan aziyat chekkan bemorlar haqida ma'lumot to'pladingiz. Davolash kursi davomida bemorlarga 5 xil doridan biri ijobiy ta'sir qildi.
#
#
# Sizning vazifangiz, xuddi shu kasallik bilan kasallangan kelajakdagi bemorga qaysi dori mos kelishi mumkinligini aniqlaydigan model yaratish. Ushbu muammo ko'p toifali klassifikator (multiclass classification) yordamida xal qilinadi.
#
#
# Model yaratish uchun Decision Tree algoritmidan foydalanamiz.

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import tree
from matplotlib import pyplot as plt
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/drug200.csv")
df.sample(10)
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 180   22   F    HIGH      NORMAL   22.818  drugY
# 100   31   M    HIGH      NORMAL   11.871  drugA
# 189   64   M    HIGH      NORMAL   20.932  drugY
# 123   36   F  NORMAL        HIGH   16.753  drugY
# 135   74   M     LOW      NORMAL   11.939  drugX
# 15    16   F    HIGH      NORMAL   15.516  drugY
# 110   50   M    HIGH        HIGH    7.490  drugA
# 39    15   M  NORMAL        HIGH    9.084  drugX
# 102   28   F     LOW        HIGH   13.127  drugC
# 36    32   M    HIGH      NORMAL    9.445  drugA

# %% [markdown]
# Ustunlar:
#
# Age - yosh
#
# Sex - jins
#
# BP - qon bosimi
#
# Cholesterol - qondagi xolesterol
#
# Na_to_K - organizmdagi natriy miqdorining kaliyga nisbati

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
df['Drug'].value_counts()
# Out:
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %%
df.shape
# Out:
# (200, 6)

# %%
encoder = LabelEncoder()
df['Sex'] = encoder.fit_transform(df['Sex'].values)
df['BP'] = encoder.fit_transform(df['BP'].values)
df['Cholesterol'] = encoder.fit_transform(df['Cholesterol'].values)
df.sample(5)
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 139   69    0   2            0   10.065  drugX
# 90    62    1   2            0   16.594  drugY
# 135   74    1   1            1   11.939  drugX
# 158   59    0   1            0   10.444  drugC
# 67    17    1   2            1   10.832  drugX

# %%
x = df.drop(columns='Drug',axis=1)
y = df['Drug']
x.head()
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K
# 0   23    0   0            0   25.355
# 1   47    1   1            0   13.093
# 2   47    1   1            0   10.114
# 3   28    0   2            0    7.798
# 4   61    0   1            0   18.043

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.2,random_state=12)

# %%
tree_model = DecisionTreeClassifier()
tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = tree_model.predict(x_test)

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#        drugA       0.89      1.00      0.94        17
#        drugB       1.00      0.86      0.92        14
#        drugC       0.55      0.46      0.50        13
#        drugX       0.85      0.89      0.87        45
#        drugY       1.00      1.00      1.00        71
#
#     accuracy                           0.91       160
#    macro avg       0.86      0.84      0.85       160
# weighted avg       0.91      0.91      0.91       160

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_predict))
# Out:
# 0.9125

# %%
predict = cross_val_predict(estimator = tree_model, X= x, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        drugA       0.92      1.00      0.96        23
#        drugB       1.00      0.88      0.93        16
#        drugC       1.00      1.00      1.00        16
#        drugX       1.00      0.98      0.99        54
#        drugY       0.99      1.00      0.99        91
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.97      0.98       200
# weighted avg       0.99      0.98      0.98       200

# %%
from sklearn import metrics
print(metrics.accuracy_score(y, predict))
# Out:
# 0.985
